# %%
class FoodItem:
    def __init__(self, name, quantity, price, discount, stock):
        self.food_id = None  # FoodID will be generated automatically
        self.name = name
        self.quantity = quantity
        self.price = price
        self.discount = discount
        self.stock = stock


class Restaurant:
    def __init__(self):
        self.food_items = []

    def add_food_item(self, name, quantity, price, discount, stock):
        food_item = FoodItem(name, quantity, price, discount, stock)
        food_item.food_id = len(self.food_items) + 1  # Generating FoodID automatically
        self.food_items.append(food_item)
        print("Food item added successfully.")

    def edit_food_item(self, food_id, name, quantity, price, discount, stock):
        for food_item in self.food_items:
            if food_item.food_id == food_id:
                food_item.name = name
                food_item.quantity = quantity
                food_item.price = price
                food_item.discount = discount
                food_item.stock = stock
                print("Food item edited successfully.")
                return
        print("Food item not found.")

    def view_food_items(self):
        if not self.food_items:
            print("No food items available.")
        else:
            print("List of food items:")
            for food_item in self.food_items:
                print(f"FoodID: {food_item.food_id}")
                print(f"Name: {food_item.name}")
                print(f"Quantity: {food_item.quantity}")
                print(f"Price: {food_item.price}")
                print(f"Discount: {food_item.discount}")
                print(f"Stock: {food_item.stock}")
                print("")

    def remove_food_item(self, food_id):
        for food_item in self.food_items:
            if food_item.food_id == food_id:
                self.food_items.remove(food_item)
                print("Food item removed successfully.")
                return
        print("Food item not found.")


# Example usage
restaurant = Restaurant()

# Add new food items
restaurant.add_food_item("Tandoori Chicken", "4 pieces", 240, 10, 50)
restaurant.add_food_item("Vegan Burger", "1 piece", 320, 15, 30)
restaurant.add_food_item("Truffle Cake", "500gm", 900, 0, 20)

# Edit food items
restaurant.edit_food_item(2, "Vegan Burger", "2 pieces", 350, 20, 25)

# View the list of all food items
restaurant.view_food_items()

# Remove a food item
restaurant.remove_food_item(1)
# Out:
# Food item added successfully.
# Food item added successfully.
# Food item added successfully.
# Food item edited successfully.
# List of food items:
# FoodID: 1
# Name: Tandoori Chicken
# Quantity: 4 pieces
# Price: 240
# Discount: 10
# Stock: 50
#
# FoodID: 2
# Name: Vegan Burger
# Quantity: 2 pieces
# Price: 350
# Discount: 20
# Stock: 25
#
# FoodID: 3
# Name: Truffle Cake
# Quantity: 500gm
# Price: 900
# Discount: 0
# Stock: 20
#
# Food item removed successfully.

# %% [markdown]
# In the above code:
#
# The FoodItem class represents a single food item with properties like food_id, name, quantity, price, discount, and stock.
# The Restaurant class manages the list of food items and provides the required functionalities.
# The add_food_item method adds a new food item to the list, automatically generating the food_id using the length of the existing food items.
# The edit_food_item method modifies the details of a food item based on the given food_id.
# The view_food_items method displays the list of all food items along with their details.
# The remove_food_item method removes a food item from the list based on the given food_id.
# You can run the code and see the output to verify the functionality of each operation. Feel free to modify or expand the code as per your specific requirements.

# %%
class User:
    def __init__(self, full_name, phone_number, email, address, password):
        self.full_name = full_name
        self.phone_number = phone_number
        self.email = email
        self.address = address
        self.password = password
        self.order_history = []

    def place_order(self, restaurant, selected_items):
        ordered_items = []
        total_price = 0

        for item_index in selected_items:
            if item_index < 1 or item_index > len(restaurant.food_items):
                print(f"Invalid item index: {item_index}")
                continue

            food_item = restaurant.food_items[item_index - 1]
            ordered_items.append(food_item)
            total_price += food_item.price

        order = {"items": ordered_items, "total_price": total_price}
        self.order_history.append(order)
        print("Order placed successfully.")

    def view_order_history(self):
        if not self.order_history:
            print("No order history available.")
        else:
            print("Order History:")
            for index, order in enumerate(self.order_history):
                print(f"Order {index + 1}:")
                for item in order["items"]:
                    print(f"Food: {item.name} ({item.quantity}) - Price: {item.price}")
                print(f"Total Price: {order['total_price']}")
                print("")

    def update_profile(self, full_name, phone_number, email, address, password):
        self.full_name = full_name
        self.phone_number = phone_number
        self.email = email
        self.address = address
        self.password = password
        print("Profile updated successfully.")


class Restaurant:
    def __init__(self):
        self.food_items = []

    def add_food_item(self, name, quantity, price, discount, stock):
        food_item = FoodItem(name, quantity, price, discount, stock)
        food_item.food_id = len(self.food_items) + 1  # Generating FoodID automatically
        self.food_items.append(food_item)
        print("Food item added successfully.")

    # Rest of the code for edit, view, and remove food items


class FoodItem:
    def __init__(self, name, quantity, price, discount, stock):
        self.food_id = None  # FoodID will be generated automatically
        self.name = name
        self.quantity = quantity
        self.price = price
        self.discount = discount
        self.stock = stock


# Example usage
restaurant = Restaurant()

# Add new food items
restaurant.add_food_item("Tandoori Chicken", "4 pieces", 240, 10, 50)
restaurant.add_food_item("Vegan Burger", "1 piece", 320, 15, 30)
restaurant.add_food_item("Truffle Cake", "500gm", 900, 0, 20)

# User registration
user = User("John Doe", "1234567890", "johndoe@example.com", "123 Street, City", "password")

# Place New Order
selected_items = [2, 3]
user.place_order(restaurant, selected_items)

# View Order History
user.view_order_history()

# Update Profile
user.update_profile("John Doe", "9876543210", "johndoe@example.com", "456 Avenue, City", "newpassword")
# Out:
# Food item added successfully.
# Food item added successfully.
# Food item added successfully.
# Order placed successfully.
# Order History:
# Order 1:
# Food: Vegan Burger (1 piece) - Price: 320
# Food: Truffle Cake (500gm) - Price: 900
# Total Price: 1220
#
# Profile updated successfully.

# %% [markdown]
# In the above code:
#
# The User class represents a user of the food ordering app. It has properties such as full_name, phone_number, email, address, password, and order_history.
# The Restaurant class
